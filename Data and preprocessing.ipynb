# %% [markdown]
# ## Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import spacy
from nltk.tokenize import word_tokenize
import nltk
from nltk.corpus import stopwords
from gensim.models import CoherenceModel
from gensim.models.nmf import Nmf
from gensim.corpora.dictionary import Dictionary
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup

# %% [markdown]
# ### House Hearings

# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# Define the directory where your files are located
directory_path_house = "Data/House Hearings"

house_documents = []

# Loop through each file in the directory
for filename in os.listdir(directory_path_house):
    if filename.endswith('.txt'):  # Check if the file is a text file
        file_path = os.path.join(directory_path_house, filename)
        
        # Read the file
        with open(file_path, 'r', encoding='utf-8') as file:
            file_content = file.read()

        # Parse the HTML content
        soup = BeautifulSoup(file_content, 'html.parser')

        # Extract the text
        house_text = soup.get_text()

        # Append the text to the documents list
        # The ID will be assigned later, based on the DataFrame's index
        house_documents.append({
            'text': house_text,
            'congress': 'house'
        })

# Create a DataFrame
df_house_documents = pd.DataFrame(house_documents)

# Assign the row number as the 'id'
df_house_documents['id'] = df_house_documents.index

# Show the DataFrame to verify its structure
df_house_documents
# Out:
#                                                 text congress  id
# 0  \n\n - EXAMINING THE FISCAL YEAR 2024 STATE AN...    house   0
# 1  \n\n - EXPOSING PUTIN'S CRIMES: EVIDENCE OF RU...    house   1
# 2  \n\n - MARKUP OF VARIOUS MEASURES\n[House Hear...    house   2
# 3  \n\n - MARKUP OF VARIOUS MEASURES\n[House Hear...    house   3
# 4  \n\n - OVERSIGHT, TRANSPARENCY, AND ACCOUNTABI...    house   4
# 5  \n\n - RUSSIA'S ALPINE ASSETS: MONEY LAUNDERIN...    house   5
# 6  \n\n - STABILITY AND SECURITY IN THE WESTERN. ...    house   6
# 7  \n\n - THE STATE OF AMERICAN DIPLOMACY IN 2023...    house   7
# 8  \n\n - THE VILNIUS SUMMIT AND WAR IN UKRAINE: ...    house   8
# 9  \n\n - HAMAS' HOSTAGES, PUTIN'S PRISONERS, AND...    house   9

# %% [markdown]
# ### Senate Hearings

# %%
# Define the directory where your files are located
directory_path_senate = "Data/Senate Hearings"

documents_senate = []

# Loop through each file in the directory
for filename in os.listdir(directory_path_senate):
    if filename.endswith('.txt'):  # Check if the file is a text file
        file_path = os.path.join(directory_path_senate, filename)
        
        # Read the file
        with open(file_path, 'r', encoding='utf-8') as file:
            file_content = file.read()

        # Parse the HTML content
        soup = BeautifulSoup(file_content, 'html.parser')

        # Extract the text
        senate_text = soup.get_text()

        # Append the text to the documents list
        # The ID will be assigned later, based on the DataFrame's index
        documents_senate.append({
            'text': senate_text,
            'congress': 'senate'
        })

# Create a DataFrame
df_documents_senate = pd.DataFrame(documents_senate)

# Assign the row number as the 'id'
df_documents_senate['id'] = df_documents_senate.index

# Show the DataFrame to verify its structure
df_documents_senate
# Out:
#                                                 text congress  id
# 0  \n\n - ACCOUNTABILITY FOR RUSSIAN ATROCITIES I...   senate   0
# 1  \n\n - ALIGNING TRANSATLANTIC APPROACHES ON CH...   senate   1
# 2  \n\n - AMERICAN DIPLOMACY AND GLOBAL LEADERSHI...   senate   2
# 3  \n\n - ASSESSING U.S. POLICY TOWARDS THE WESTE...   senate   3
# 4  \n\n - COUNTERING RUSSIAN AGGRESSION: UKRAINE ...   senate   4
# 5  \n\n - EXAMINING U.S. AND GLOBAL COMMITMENTS T...   senate   5
# 6  \n\n - REVIEW OF THE FISCAL YEAR 2024 UNITED S...   senate   6
# 7  \n\n - THE GLOBAL INFORMATION WARS: IS THE U.S...   senate   7
# 8  \n\n - U.S. SUPPORT OF DEMOCRACY AND HUMAN RIG...   senate   8
# 9  \n\n - WHAT COMES NEXT FOR U.S. POLICY TOWARDS...   senate   9

# %% [markdown]
# ### Joint Hearings

# %%
# Define the directory where your files are located
directory_path_joint = "Data/Joint Hearings"

documents_joint = []

# Loop through each file in the directory
for filename in os.listdir(directory_path_joint):
    if filename.endswith('.txt'):  # Check if the file is a text file
        file_path = os.path.join(directory_path_joint, filename)
        
        # Read the file
        with open(file_path, 'r', encoding='utf-8') as file:
            file_content = file.read()

        # Parse the HTML content
        soup = BeautifulSoup(file_content, 'html.parser')

        # Extract the text
        joint_text = soup.get_text()

        # Append the text to the documents list
        # The ID will be assigned later, based on the DataFrame's index
        documents_joint.append({
            'text': joint_text,
            'congress': 'joint'
        })

# Create a DataFrame
df_documents_joint = pd.DataFrame(documents_joint)

# Assign the row number as the 'id'
df_documents_joint['id'] = df_documents_joint.index

# Show the DataFrame to verify its structure
df_documents_joint
# Out:
#                                                 text congress  id
# 0  \n\n - CHURCH, STATE, AND RUSSIA'S WAR ON UKRA...    joint   0
# 1  \n\n - COUNTERING RUSSIA'S TERRORISTIC MERCENA...    joint   1
# 2  \n\n - HAS THE UNITED NATIONS FAILED UKRAINE A...    joint   2
# 3  \n\n - SUPPORTING ISRAEL AND UKRAINE AGAINST T...    joint   3
# 4  \n\n - VLADIMIR KARA-MURZA: PUTIN'S PERSONAL P...    joint   4
